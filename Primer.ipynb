# %%
import functions as f
from pathlib import Path
import cv2
from IPython.display import Image

# %%
img_path = Path.cwd().joinpath('data').joinpath('diplom_data').joinpath('raw')
img1 = cv2.imread(str(img_path.joinpath('005.jpg')))
img2 = cv2.imread(str(img_path.joinpath('004.jpg')))
img3 = cv2.imread(str(img_path.joinpath('007.jpg')))
f.solve(img1)
Image(str(img_path.joinpath('005.jpg')))
# Out:
# Символы: [3, 1, _, 2, +, 4, 3]
# Выражение: ((1**(2))/(3)+4**(3))
# Ответ: 64.33333333333333

# %%
f.solve(img2)
Image(str(img_path.joinpath('004.jpg')))
# Out:
# Символы: [2, 4, 3]
# Выражение: (2**(4**(3)))
# Ответ: 18446744073709551616

# %%
f.solve(img3)
Image(str(img_path.joinpath('007.jpg')))
# Out:
# Символы: [2, +, 3, +, 4, -, 3, _, 2]
# Выражение: (2+3+4-(2)/(3))
# Ответ: 8.333333333333334
